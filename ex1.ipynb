# %% [markdown]
# <a href="https://colab.research.google.com/github/GiaHan2702/lab1_intro_python/blob/main/ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Find local maxima of given array

# %%
import numpy as np
import matplotlib.pyplot as plt
y= np.array([1,3,7,1,2,6,0,1])
x=np.array([0,1,2,3,4,5,6,7])
print(x)
print(y)
plt.plot(x, y, 'r', markersize= 3, marker = 'o')
plt.show()  
for i in y-1:
  if y[i]> y[i-1] and y[i]>y[i+1]:
    print("local max of array is at x and y respectively:",i,y[i])
# Out:
# [0 1 2 3 4 5 6 7]
# [1 3 7 1 2 6 0 1]
# local max of array is at x and y respectively: 2 7
# local max of array is at x and y respectively: 5 6

# %% [markdown]
# cach 2: enter size, elements of array

# %%
import numpy as np
import matplotlib.pyplot as plt

def findLocalMaxima(n, arr):
	max = []
	for i in range(1, n-1):
		# Condition for local maxima
		if(arr[i-1] < arr[i] > arr[i + 1]):
			max.append(arr[i])
		# Print all the local maxima and
		# local minima indexes stored
	if(len(max) > 0):
		print("Points of Local maxima is at y=",max)
	else:
		print("There are no points of"\
			" Local maxima.")
lstx=[]
N = int(input("Enter number of elements x : "))

for i in range(0, N):
    elex = int(input())
  
    lstx.append(elex) # adding the element
   
print(lstx)
x=np.array([range(0,N)])
print("print x")
print(x)
y= np.array([lstx])
print("print y")
print(y)
plt.plot(x, y, 'r-', markersize= 3, marker = 'o')
plt.show() 

findLocalMaxima(N, arr)
# Out:
# Enter number of elements x : 4
# 1
# 2
# 3
# 1
# [1, 2, 3, 1]
# print x
# [[0 1 2 3]]
# print y
# [[1 2 3 1]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-a4094865ca45> in <module>
#      33 plt.show()
#      34
# ---> 35 findLocalMaxima(N, arr)
#      36
#
# <ipython-input-14-a4094865ca45> in findLocalMaxima(n, arr)
#       6         for i in range(1, n-1):
#       7                 # Condition for local maxima
# ----> 8                 if(arr[i-1] < arr[i] > arr[i + 1]):
#       9                         max.append(arr[i])
#      10                 # Print all the local maxima and
#
# IndexError: list index out of range

# %% [markdown]
# ![image.png](data:image/png;base64,...)
