# %% [markdown]
# <a href="https://colab.research.google.com/github/GiaHan2702/lab1_intro_python/blob/main/intro_ml_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# find relationship of x and y
#define mo hinh ML: model neural 1 layer, 1 neuron: units=1, shape
import numpy as np
import keras

#loss: predict, optimizer: improve predict
model = keras.Sequential ([keras.layers.Dense(units=1, input_shape=[1])]) 
model.compile(optimizer='sgd', loss='mean_squared_error')

xs=np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0 ], dtype=float)
ys=np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0 ], dtype=float)

# try 500 times, find rela
model.fit(xs,ys, epochs=500)
# find x=10 => y=? => 18.982376
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 486ms/step - loss: 11.6851
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 9.4145
# Epoch 3/500
# 1/1 [==============================] - 0s 14ms/step - loss: 7.6235
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 6.2100
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0936
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2110
# Epoch 7/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.5124
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.9587
# Epoch 9/500
# 1/1 [==============================] - 0s 16ms/step - loss: 2.5190
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1692
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8901
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6668
# ...

# %%
import tensorflow as tf
from tensorflow import keras
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
#train_labels: 09= ankle boot

model = keras.Sequential([
    keras.layers.Flatter(input_shape=(28,28)),
    
])
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
import tensorflow as tf
from tensorflow import keras
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
#train_labels: 09= ankle boot

# size of picture 28x28; 10: so loai sp khac nhau trong data
# output: 10 gtri khac nhau
#softmax: pick max value => output proba 1/10 sp => output=1 for max
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10,activation=tf.nn.softmax)
])
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(train_images, train_labels, epochs=5)
#evaluate: test mo hinh hd tot hay k
#nhan biet anh: ham predict
test_loss, test_acc= model.evaluate(test_images, test_labels)
predictions= model.predict(my_images)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 27.6998
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 27.6999
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 27.7000
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 27.7000
# Epoch 5/5
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 27.7000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-9846fe0f4806> in <module>
#      17 #evaluate: test mo hinh hd tot hay k
#      18 #nhan biet anh: ham predict
# ---> 19 test_loss, test_acc= model.evaluate(test_images, test_labels)
#      20 predictions= model.predict(my_images)
#
# TypeError: cannot unpack non-iterable float object
